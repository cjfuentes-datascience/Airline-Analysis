# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math

# %%
flight = pd.read_csv(r'C:\Users\Carlos\Documents\Python Projects\Airline Analysis\flight.csv')

# %%
flight
# Out:
#         miles  passengers  delay inflight_meal inflight_entertainment  \
# 0         792         172      0            No                    Yes
# 1        3163         214      0            No                    Yes
# 2        1832         212      0            No                    Yes
# 3         925         213      0            No                    Yes
# 4         967         217      0           Yes                    Yes
# ...       ...         ...    ...           ...                    ...
# 129775    674         217   1487            No                    Yes
# 129776   2125         208   1479            No                    Yes
# 129777   1702         220   1501            No                    Yes
# 129778   2709         205   1484            No                    Yes
# 129779   4005         214   1490            No                    Yes
#
#        inflight_wifi day_of_week redeye weekend  coach_price  \
# 0                Yes      Sunday    Yes     Yes      338.820
# 1                Yes      Sunday     No     Yes      472.655
# 2                 No      Friday     No     Yes      351.960
# 3                Yes    Saturday     No     Yes      387.835
# 4                Yes      Monday     No      No      374.735
# ...              ...         ...    ...     ...          ...
# 129775           Yes      Friday     No     Yes      383.240
# 129776           Yes      Friday     No     Yes      397.825
# 129777           Yes      Friday     No     Yes      380.980
# 129778           Yes    Saturday     No     Yes      485.185
# 129779           Yes    Saturday     No     Yes      446.395
#
#         firstclass_price  hours
# 0                1571.02      1
# 1                1663.70      6
# 2                1429.86      3
# 3                1558.76      2
# 4                1245.58      2
# ...                  ...    ...
# 129775           1478.70      1
# 129776           1616.01      4
# 129777           1481.49      3
# 129778           1589.70      5
# 129779           1677.54      7
#
# [129780 rows x 12 columns]

# %% [markdown]
# What do coach ticket prices look like?

# %%
sns.histplot(flight.coach_price)
plt.show()
plt.close()

# %% [markdown]
# Now visualize the coach ticket prices for flights that are 8 hours long.

# %%
sns.histplot(flight.coach_price[flight.hours == 8])
plt.show()
plt.close()

# %% [markdown]
# How are flight delay times distributed?

# %%
sns.histplot(flight.delay[flight.delay < 500])
plt.show()
plt.close()

# %% [markdown]
# Create a visualization that shows the relationship between coach and first-class prices

# %%
sns.lmplot(x = "coach_price", y = "firstclass_price", data = flight, line_kws={'color': 'black'})
plt.show()
plt.clf()

# %% [markdown]
# What is the relationship between coach prices and inflight features— inflight meal, inflight entertainment, and inflight WiFi?

# %%
sns.histplot(x='coach_price', data = flight, hue = flight.inflight_meal)
plt.show()
plt.close()

sns.histplot(x='coach_price', data = flight, hue = flight.inflight_entertainment)
plt.show()
plt.close()

sns.histplot(x='coach_price', data = flight, hue = flight.inflight_wifi)
plt.show()
plt.close()

# %% [markdown]
# How does the number of passengers change in relation to the length of flights?

# %%
sns.lmplot(x='hours', y='passengers', data = flight, x_jitter = 0.25, scatter_kws={"s": 5, "alpha":0.2}, fit_reg = False)
plt.show()
plt.close()

# %% [markdown]
# Visualize the relationship between coach and first-class prices on weekends compared to weekdays.

# %%
sns.lmplot(x='coach_price', y='firstclass_price', hue = 'weekend', data = flight, fit_reg=False)
plt.show()
plt.close()

# %% [markdown]
# How do coach prices differ for redeyes and non-redeyes on each day of the week?

# %%
sns.boxplot(x = "day_of_week", y = "coach_price", hue = "redeye", data = flight)
plt.show()
plt.close()
